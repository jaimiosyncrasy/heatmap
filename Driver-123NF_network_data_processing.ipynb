# %%
# 2.27.21
# This 123NF driver has all the funcs, whereas driver_code_forPaper-blank.ipynb has only the 123NF for heatmap paper

# %%
import importlib
import numpy as np
import math as m
import statistics as st
import cmath
import matplotlib.pyplot as plt 
import itertools
import random
from operator import add
from graphviz import Source, render
import pydot

import datetime
import time

import sys
sys.path.append('py_modules') # below modules are in this folder
#print(sys.path)
import setup_nx # your own module, setup.nx.py
importlib.reload(setup_nx)
import my_feeder_funcs as ff
import my_impedance_funcs as imp
import my_configVis_funcs as vis
import my_detControlMatExistence_funcs as ctrl
import my_detLznRange_funcs as lzn
import my_heatmapSetup_funcs as hm

# %%
# [Essential] specify input feeder data for IEEE 123-node test feeder

# Enter the path/name of the impedance model data (excel file)
filepath = "feeder_impedance_models/"
modelpath = filepath + "004_GB_IEEE123_OPAL.xls"

# load data is not actually used in assessment, but the feeder object builds variables to hold load info
loadfolder = filepath
loadpath = filepath + '004_123NF_PVpen100_nocloud_minutewise_whead.csv'
headerpath = filepath + '004_GB_IEEE123_time_header.csv'
load_data = loadpath

#file_name = string specifying name of dot file created when make_graph() is called
file_name = '123NF'
#file_name = 'demo123NF.dot'

# Specify substation kV, kVA bases, name, and the number of timesteps in the load data'
Vbase_ll = 4160
Vbase = Vbase_ll / np.sqrt(3)
Sbase = 5000/3
substation_name = 'bus_150'
timesteps = 1

# initialize some variables
ts = time.time()
print(datetime.datetime.fromtimestamp(ts))
plot = 0 #turn plot on/off
depths = {}
leaves = []
# Out:
# 2021-03-01 08:54:59.874829

# %%
# [ESSENTIAL] create feeder object

fin_feeder = ff.feeder_init(modelpath,loadfolder,loadpath,timesteps,Vbase_ll,Sbase,depths,leaves)
print("Finished initializing feeder")
ff.make_graph(fin_feeder, file_name)
node_index_map = hm.createNodeIndexMap(fin_feeder) #node indices for indicMat and F matrix
R,X=hm.createRXmatrices_3ph(fin_feeder, node_index_map,depths)

#print('depths=',depths) # check this is populated, lists how far each node is from substation
#print('depths length=',len(depths))

# print list of first 10 buses in network
count = 0 
for i in fin_feeder.network:    
    print(i) 
    count += 1
    if count >= 10:
        break
    
import csv  # jaimie do you need this?
graph = fin_feeder.network
# Out:
#   File "C:\Users\jaimi\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\jaimi\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\jaimi\Anaconda3\lib\asyncio\base_events.py", line 538, in run_forever
#     self._run_once()
#   File "C:\Users\jaimi\Anaconda3\lib\asyncio\base_events.py", line 1782, in _run_once
#     handle._run()
#   File "C:\Users\jaimi\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\jaimi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-dafb20e2ed27>", line 3, in <module>
#     fin_feeder = ff.feeder_init(modelpath,loadfolder,loadpath,timesteps,Vbase_ll,Sbase,depths,leaves)
#   File "py_modules\my_feeder_funcs.py", line 42, in feeder_init
#     Vbase_ll,Sbase,refphasor,Psat_nodes,Qsat_nodes,PVforecast, depths, leaves)
#   File "py_modules\setup_nx.py", line 69, in __init__
#     self.loaddict = loadbuilderPQ(self.modeldata, self.busdict, loadpath, timesteps, timestepcur)
#   File "py_modules\setup_nx.py", line 612, in loadbuilderPQ
#     Z = np.conj(np.square(iload.node.kVbase_phg)*1000/S)
#   File "C:\Users\jaimi\Anaconda3\lib\warnings.py", line 110, in _showwarnmsg
#     msg.file, msg.line)
#   File "py_modules\setup_nx.py", line 30, in warn_with_traceback
#     traceback.print_stack(file=log)
# py_modules\setup_nx.py:612: RuntimeWarning: overflow encountered in int_scalars
#   Z = np.conj(np.square(iload.node.kVbase_phg)*1000/S)
# Finished initializing feeder
# bus_1
# bus_10
# bus_100
# bus_101
# bus_102
# bus_103
# bus_104
# bus_105
# bus_106
# bus_107

# %%
# for converting a .dot to .png
(graph,) = pydot.graph_from_dot_file('generated_figs/heatmap_colocated_123NF_badbranch')
graph.write_png('generated_figs/heatmap_colocated_123NF_badbranch.png')
(graph,) = pydot.graph_from_dot_file('generated_figs/heatmap_colocated_123NF_goodbranch')
graph.write_png('generated_figs/heatmap_colocated_123NF_goodbranch.png')

# %%
# write busnames into a csv
# with open("123NF_busList.csv", 'w', newline='') as csvfile:
#     spamwriter = csv.writer(csvfile, delimiter='-',
#                             quotechar='|', quoting=csv.QUOTE_MINIMAL)
#     spamwriter.writerows(graph.nodes)

# %%
# Print 3-phase node_index table
my_buses=list(node_index_map.keys())
my_list=list(node_index_map.values())
list1 = [(i+1) * 3-2 for i in my_list]
list2 = [(i+1) * 3-1 for i in my_list]
list3 = [(i+1) * 3-0 for i in my_list]
for my_buses,list1, list2,list3 in zip(my_buses,list1,list2,list3):
    print(my_buses,list1, list2,list3)
#Table format: [bus_name, phaseA idx, phaseB idx, phaseC idx]
# indices are shifted by 1 to be for MATLAB (starts at 1 not 0)

# R is of size 387, which is 129*3, so set n=129
n=129
A, B = hm.setupStateSpace(n,fin_feeder, node_index_map,depths)
print('R = '+str(R))
print('X = '+str(X))
print('A = '+str(A))
print('B = '+str(B))
print(A.shape)
print(B.shape)

# write A and B matrices to csv
#np.savetxt("123NF_Amat.csv", A, delimiter=",")
#np.savetxt("123NF_Bmat.csv", B, delimiter=",")

# Save R and X matrices to csv to import into matlab
# np.savetxt reference: https://thispointer.com/how-to-save-numpy-array-to-a-csv-file-using-numpy-savetxt-in-python/
#np.savetxt('Rmat_123NF.csv', R, delimiter=',')
#np.savetxt('Xmat_123NF.csv', X, delimiter=',')

# %%
# [Optional] run impedance-related functions
slack_bus = None
for bus_name, depth in depths.items():
    if depth == 0:
        slack_bus = bus_name
        break
        
# -------------------- now we call functions: ---------------------------------------------
#print(depths)
# modify node names when change feeders
#plot_histogram_RX_ratios(fin_feeder, leaves_only = True)
print('Z between buses:')
print(np.around(imp.get_total_impedance_between_two_buses(fin_feeder, 'bus_37', 'bus_15',depths),2))
print('\nBus 49 Z to substation:')
print(np.around(imp.get_total_impedance_from_substation(fin_feeder, 'bus_49',depths),2))
print('\nR/X ratio of bus 49 to substation:')
print(imp.get_RX_ratio_tosubst(fin_feeder,'bus_49',depths))
print('R/X Ratios:')
print('\n67 to 79: ')
print(imp.get_RX_ratio_between_two_buses(fin_feeder, 'bus_67', 'bus_79',depths))

# %%
# Rx ratio and phase coupling ratio informs bad branches
branches = vis.assign_network_branches(fin_feeder, substation_name)
for branch in branches:
    if 'bus_150'in branch:
        branch.remove('bus_150')
        branch.remove('bus_149')
rx_dic = {}
phase_ratios = vis.phaseCouplingPerNode(fin_feeder, depths, file_name)
graphNodes_nosub = hm.remove_subst_nodes(fin_feeder, file_name) # dont consider substation nodes, node 650 and 651 for 13NF
for node_name in graphNodes_nosub:
    foo=list((imp.get_RX_ratio_tosubst(fin_feeder, node_name, depths)).values())
    rx_3ph=np.array(foo).astype('float')
    rx_3ph[rx_3ph==0]=np.nan # assign NaN to all zeros
    rx_dic[node_name]=np.nanmean(rx_3ph) # nanmean isgnores nans, now scalar metric for each node
    
    ph_3ph=phase_ratios[node_name].astype('float')
    ph_3ph[ph_3ph==0]=np.nan # assign NaN to all zeros
    phase_ratios[node_name]=np.nanmean(ph_3ph) # nanmean isgnores nans, now scalar metric for each node
    
vis.createColorMap(fin_feeder, phase_ratios, 'phase_coupling')
vis.createColorMap(fin_feeder, rx_dic, 'rx')

#------------ make mixed colormap -----------
normd_phase_ratios = {}
normd_rx = {}
avg_phase = np.nanmean(list(phase_ratios.values()))
avg_rx = np.nanmean(list(rx_dic.values()))

for key, val in phase_ratios.items():
    if not np.isnan(val):
        normd_phase_ratios[key] = val/avg_phase
for key, val in rx_dic.items():
    if not np.isnan(val):
        normd_rx[key] = val/avg_rx

mixed_vals = {}
for node in graphNodes_nosub:
    mixed_vals[node] = normd_phase_ratios[node] + normd_rx[node]
vis.createColorMap(fin_feeder, mixed_vals, 'mixed')
# colormaps show up in generated_figs folder

# %%
# make table of branches, ratios, and num used

# print('branches table:') # format into a table with index and branch nodes
# i=0
# for br in branches:
#     print(i,',',br)
#     i+=1
    
num_used=np.full((1, len(graphNodes_nosub)),-1) # placeholder

print('bus | rx_rat | ph_rat | num_used')
print('large and small rx_rat:')
foo1=sorted(normd_rx, key=normd_rx.get, reverse=True)[:3] # get keys of 3 largest values of dict
for node in foo1:
    print(node,np.around(normd_rx[node],3),np.around(normd_phase_ratios[node],3),-1)

foo2=sorted(normd_rx, key=normd_rx.get, reverse=False)[:3] # get keys of 3 smallest values of dict
for node in foo2:
    print(node,np.around(normd_rx[node],3),np.around(normd_phase_ratios[node],3),-1)

print('large and small ph_rat:')
foo3=sorted(normd_phase_ratios, key=normd_phase_ratios.get, reverse=True)[:3] # get keys of 5 largest values of dict
for node in foo3:
    print(node,np.around(normd_rx[node],3),np.around(normd_phase_ratios[node],3),-1)

foo4=sorted(normd_phase_ratios, key=normd_phase_ratios.get, reverse=False)[:3] # get keys of 5 smallest values of dict
for node in foo4:
    print(node,np.around(normd_rx[node],3),np.around(normd_phase_ratios[node],3),-1)

print('large and small sum_rat:')
foo3=sorted(mixed_vals, key=mixed_vals.get, reverse=True)[:3] # get keys of 5 largest values of dict
for node in foo3:
    print(node,np.around(normd_rx[node],3),np.around(normd_phase_ratios[node],3),-1)

foo4=sorted(mixed_vals, key=mixed_vals.get, reverse=False)[:3] # get keys of 5 smallest values of dict
for node in foo4:
    print(node,np.around(normd_rx[node],3),np.around(normd_phase_ratios[node],3),-1)

    
# for node in graphNodes_nosub:
#     print(node,np.around(normd_phase_ratios[node],3),np.around(normd_rx[node],3),-1)

# %%
Source.from_file('colorMap_rx') # display colormap to see good/bad branches 
Source.from_file('colorMap_phase_coupl') # display colormap to see good/bad branches
Source.from_file('colorMap_mixed') # display colormap to see good/bad branches

# %%
# temp: create slide 7
# good vs. bad branch scenario
all_act_locs = ['bus_8','bus_53','bus_57','bus_66'] # on bad branch

# here we set act_locs as the existing actuators
feas_configs, heatMapNames=hm.find_good_colocated(fin_feeder, all_act_locs, node_index_map, substation_name, depths,file_name, Vbase_ll, Sbase, load_data, headerpath, modelpath)
# Out:
# evaluating act and perf colocated at  ['bus_1']
# Config good!
# Best F is (Fp Fq)= [0.37902374 0.19855767]
# num feas= [[28.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_10']
# Config good!
# Best F is (Fp Fq)= [0.34486591 0.18066548]
# num feas= [[35.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_100']
# Config good!
# Best F is (Fp Fq)= [0.25903497 0.13570641]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_101']
# Config good!
# Best F is (Fp Fq)= [0.27747625 0.14536613]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_102']
# Config good!
# Best F is (Fp Fq)= [0.26783439 0.14031563]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_103']
# Config good!
# Best F is (Fp Fq)= [0.26680856 0.13977829]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_104']
# Config good!
# Best F is (Fp Fq)= [0.26553519 0.13911129]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_105']
# Config good!
# Best F is (Fp Fq)= [0.27174725 0.14236522]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_106']
# Config good!
# Best F is (Fp Fq)= [0.26120106 0.13684103]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_107']
# Config good!
# Best F is (Fp Fq)= [0.26003189 0.13622861]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_108']
# Config good!
# Best F is (Fp Fq)= [0.26598351 0.13934612]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_109']
# Config good!
# Best F is (Fp Fq)= [0.25501306 0.1335997 ]
# num feas= [[7.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_11']
# Config good!
# Best F is (Fp Fq)= [0.34486591 0.18066548]
# num feas= [[35.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_110']
# Config good!
# Best F is (Fp Fq)= [0.25238827 0.13222481]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_111']
# Config good!
# Best F is (Fp Fq)= [0.25141999 0.13171761]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_112']
# Config good!
# Best F is (Fp Fq)= [0.25026967 0.13111506]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_113']
# Config good!
# Best F is (Fp Fq)= [0.25071708 0.13134942]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_114']
# Config good!
# Best F is (Fp Fq)= [0.2476404  0.12973783]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_12']
# Config good!
# Best F is (Fp Fq)= [0.34613463 0.18133004]
# num feas= [[35.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_13']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_135']
# Config good!
# Best F is (Fp Fq)= [0.30705737 0.160861  ]
# num feas= [[24.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_14']
# Config good!
# Best F is (Fp Fq)= [0.34684924 0.18170436]
# num feas= [[36.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_15']
# Config good!
# Best F is (Fp Fq)= [0.33404508 0.17499742]
# num feas= [[31.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_151']
# Config good!
# Best F is (Fp Fq)= [0.26110057 0.13678839]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_152']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_16']
# Config good!
# Best F is (Fp Fq)= [0.33359235 0.17476028]
# num feas= [[30.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_160']
# Config good!
# Best F is (Fp Fq)= [0.27904835 0.14618961]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_17']
# Config good!
# Best F is (Fp Fq)= [0.33359435 0.17476133]
# num feas= [[30.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_18']
# Config good!
# Best F is (Fp Fq)= [0.33789273 0.17701286]
# num feas= [[35.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_19']
# Config good!
# Best F is (Fp Fq)= [0.30813206 0.16142393]
# num feas= [[25.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_197']
# Config good!
# Best F is (Fp Fq)= [0.2728267  0.14293065]
# num feas= [[6.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_2']
# Config good!
# Best F is (Fp Fq)= [0.36665852 0.19208065]
# num feas= [[41.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_20']
# Config good!
# Best F is (Fp Fq)= [0.30642522 0.16052988]
# num feas= [[24.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_21']
# Config good!
# Best F is (Fp Fq)= [0.31260879 0.16376889]
# num feas= [[27.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_22']
# Config good!
# Best F is (Fp Fq)= [0.29816766 0.15620449]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_23']
# Config good!
# Best F is (Fp Fq)= [0.30306327 0.15876885]
# num feas= [[20.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_24']
# Config good!
# Best F is (Fp Fq)= [0.29240826 0.15318766]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_25']
# Config good!
# Best F is (Fp Fq)= [0.29623503 0.15519216]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_250']
# Config good!
# Best F is (Fp Fq)= [0.26659248 0.13966511]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_251']
# Config good!
# Best F is (Fp Fq)= [0.25842228 0.13538548]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_26']
# Config good!
# Best F is (Fp Fq)= [0.28357508 0.14856075]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_27']
# Config good!
# Best F is (Fp Fq)= [0.28603456 0.14984906]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_28']
# Config good!
# Best F is (Fp Fq)= [0.28767165 0.15070658]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_29']
# Config good!
# Best F is (Fp Fq)= [0.28380819 0.14868286]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_3']
# Config good!
# Best F is (Fp Fq)= [0.36696702 0.19224225]
# num feas= [[41.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_30']
# Config good!
# Best F is (Fp Fq)= [0.27686722 0.14504711]
# num feas= [[14.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_300']
# Config good!
# Best F is (Fp Fq)= [0.26317082 0.13787281]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_31']
# Config good!
# Best F is (Fp Fq)= [0.28458151 0.14908793]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_32']
# Config good!
# Best F is (Fp Fq)= [0.28332873 0.14843172]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_33']
# Config good!
# Best F is (Fp Fq)= [0.28187034 0.1476678 ]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_34']
# Config good!
# Best F is (Fp Fq)= [0.33553463 0.17577766]
# num feas= [[33.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_35']
# Config good!
# Best F is (Fp Fq)= [0.31323314 0.16409593]
# num feas= [[28.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_350']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_36']
# Config good!
# Best F is (Fp Fq)= [0.29848012 0.15636816]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_37']
# Config good!
# Best F is (Fp Fq)= [0.28901031 0.15140778]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_38']
# Config good!
# Best F is (Fp Fq)= [0.28851822 0.15115002]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_39']
# Config good!
# Best F is (Fp Fq)= [0.28700164 0.15035562]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_4']
# Config good!
# Best F is (Fp Fq)= [0.36476944 0.19109113]
# num feas= [[40.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_40']
# Config good!
# Best F is (Fp Fq)= [0.30088537 0.15762805]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_41']
# Config good!
# Best F is (Fp Fq)= [0.29016543 0.15201285]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_42']
# Config good!
# Best F is (Fp Fq)= [0.29382907 0.15393189]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_43']
# Config good!
# Best F is (Fp Fq)= [0.28259348 0.14804658]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_44']
# Config good!
# Best F is (Fp Fq)= [0.28634316 0.1500107 ]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_45']
# Config good!
# Best F is (Fp Fq)= [0.27807124 0.14567779]
# num feas= [[14.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_450']
# Config good!
# Best F is (Fp Fq)= [0.25676362 0.13451666]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_451']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_46']
# Config good!
# Best F is (Fp Fq)= [0.27711516 0.14517699]
# num feas= [[14.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_47']
# Config good!
# Best F is (Fp Fq)= [0.28187836 0.147672  ]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_48']
# Config good!
# Best F is (Fp Fq)= [0.27408104 0.14358769]
# num feas= [[12.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_49']
# Config good!
# Best F is (Fp Fq)= [0.27562961 0.14439884]
# num feas= [[13.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_5']
# Config good!
# Best F is (Fp Fq)= [0.36459961 0.19100218]
# num feas= [[40.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_50']
# Config good!
# Best F is (Fp Fq)= [0.26964108 0.141262  ]
# num feas= [[11.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_51']
# Config good!
# Best F is (Fp Fq)= [0.26389857 0.13825401]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_52']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_54']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_55']
# Config good!
# Best F is (Fp Fq)= [0.31544795 0.16525607]
# num feas= [[6.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_56']
# Config good!
# Best F is (Fp Fq)= [0.30705737 0.160861  ]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_58']
# Config good!
# Best F is (Fp Fq)= [0.29999449 0.1571614 ]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_59']
# Config good!
# Best F is (Fp Fq)= [0.29837411 0.15631263]
# num feas= [[19.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_6']
# Config good!
# Best F is (Fp Fq)= [0.36156144 0.18941075]
# num feas= [[40.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_60']
# Config good!
# Best F is (Fp Fq)= [0.30714253 0.16090561]
# num feas= [[12.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_61']
# Config good!
# Best F is (Fp Fq)= [0.28666221 0.15017782]
# num feas= [[12.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_610']
# Config good!
# Best F is (Fp Fq)= [0.26571739 0.13920673]
# num feas= [[6.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_62']
# Config good!
# Best F is (Fp Fq)= [0.28474582 0.149174  ]
# num feas= [[13.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_63']
# Config good!
# Best F is (Fp Fq)= [0.27657391 0.14489347]
# num feas= [[11.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_64']
# Config good!
# Best F is (Fp Fq)= [0.27488929 0.14401106]
# num feas= [[12.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_65']
# Config good!
# Best F is (Fp Fq)= [0.26645278 0.13959193]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_67']
# Config good!
# Best F is (Fp Fq)= [0.27904835 0.14618961]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_68']
# Config good!
# Best F is (Fp Fq)= [0.27997291 0.14667391]
# num feas= [[18.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_69']
# Config good!
# Best F is (Fp Fq)= [0.27893734 0.14613147]
# num feas= [[16.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_7']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_70']
# Config good!
# Best F is (Fp Fq)= [0.27736421 0.14530744]
# num feas= [[14.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_71']
# Config good!
# Best F is (Fp Fq)= [0.27523621 0.14419278]
# num feas= [[12.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_72']
# Config good!
# Best F is (Fp Fq)= [0.28413948 0.1488564 ]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_73']
# Config good!
# Best F is (Fp Fq)= [0.2733307  0.14319465]
# num feas= [[12.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_74']
# Config good!
# Best F is (Fp Fq)= [0.27187763 0.14243352]
# num feas= [[11.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_75']
# Config good!
# Best F is (Fp Fq)= [0.26994283 0.14142006]
# num feas= [[11.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_76']
# Config good!
# Best F is (Fp Fq)= [0.27612595 0.14465883]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_77']
# Config good!
# Best F is (Fp Fq)= [0.27377478 0.14342726]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_78']
# Config good!
# Best F is (Fp Fq)= [0.26041261 0.13642803]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_79']
# Config good!
# Best F is (Fp Fq)= [0.26021786 0.13632602]
# num feas= [[6.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_80']
# Config good!
# Best F is (Fp Fq)= [0.26305867 0.13781407]
# num feas= [[8.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_81']
# Config good!
# Best F is (Fp Fq)= [0.2530155  0.13255336]
# num feas= [[5.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_82']
# Config good!
# Best F is (Fp Fq)= [0.24122641 0.12637812]
# num feas= [[2.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_83']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_84']
# Config good!
# Best F is (Fp Fq)= [0.23899753 0.12521061]
# num feas= [[4.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_85']
# Config good!
# Best F is (Fp Fq)= [0.23572372 0.12349576]
# num feas= [[2.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_86']
# Config good!
# Best F is (Fp Fq)= [0.27590245 0.14454176]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_87']
# Config good!
# Best F is (Fp Fq)= [0.25851081 0.13543185]
# num feas= [[6.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_88']
# Config good!
# Best F is (Fp Fq)= [0.24372837 0.12768867]
# num feas= [[4.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_89']
# Config good!
# Best F is (Fp Fq)= [0.24734303 0.12958206]
# num feas= [[4.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_9']
# Config good!
# Best F is (Fp Fq)= [0.343942   0.18018152]
# num feas= [[35.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_90']
# Config good!
# Best F is (Fp Fq)= [0.23839827 0.12489671]
# num feas= [[3.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_91']
# Config good!
# Best F is (Fp Fq)= [0.24137295 0.12645488]
# num feas= [[2.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_92']
# Config good!
# Best F is (Fp Fq)= [0.23474784 0.12298458]
# num feas= [[1.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_93']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_94']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_95']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_96']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_97']
# Config good!
# Best F is (Fp Fq)= [0.28380592 0.14868167]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_98']
# Config good!
# Best F is (Fp Fq)= [0.27781218 0.1455421 ]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_99']
# Config good!
# Best F is (Fp Fq)= [0.27386002 0.14347191]
# num feas= [[10.]]
# num tried= 225
# evaluating act and perf colocated at  ['bus_610_']
# Config good!
# Best F is (Fp Fq)= [0.26571739 0.13920673]
# num feas= [[6.]]
# num tried= 225

# %%
all_act_locs = ['bus_8','bus_53','bus_57','bus_74'] # on good branch

# here we set act_locs as the existing actuators
feas_configs, heatMapNames=hm.find_good_colocated(fin_feeder, all_act_locs, node_index_map, substation_name, depths,file_name, Vbase_ll, Sbase, load_data, headerpath, modelpath)

# result looks like: 'heatmap_colocated' + '_' + file_name

# %%
# temp:

t = time.time()
seed=2
print('----------- Seed='+str(seed)+' ----------------------------')
max_act_config = hm.place_max_coloc_acts(seed,fin_feeder, file_name, node_index_map, depths, substation_name,Vbase_ll, Sbase, load_data, headerpath, modelpath)
elapsed = time.time() - t
print('Time elapsed=',elapsed)
# Out:
# ----------- Seed=2 ----------------------------
# evaluating actuator and performance node colocated at  ['bus_96']
# Config good!
# Best F is (Fp Fq)= [0.54203422 0.36135615]
# num feas= [[210.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_85', 'bus_96']
# Config good!
# Best F is (Fp Fq)= [0.28633734 0.19089156]
# num feas= [[196.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_97', 'bus_96', 'bus_85']
# Config good!
# Best F is (Fp Fq)= [0.22618566 0.11849963]
# num feas= [[196.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_83', 'bus_96', 'bus_85', 'bus_97']
# Config good!
# Best F is (Fp Fq)= [0.16520796 0.08655893]
# num feas= [[132.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_105', 'bus_96', 'bus_85', 'bus_97', 'bus_83']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_11', 'bus_96', 'bus_85', 'bus_97', 'bus_83']
# Config good!
# Best F is (Fp Fq)= [0.15728506 0.08240884]
# num feas= [[132.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_108', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11']
# Config good!
# Best F is (Fp Fq)= [0.13293025 0.06965156]
# num feas= [[5.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_32', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_86', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_151', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_74', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_84', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_66', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_93', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_28', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_23', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_61', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_197', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108']
# Config good!
# Best F is (Fp Fq)= [0.11636972 0.060977  ]
# num feas= [[28.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_59', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108', 'bus_197']
# Config good!
# Best F is (Fp Fq)= [0.10695158 0.05604368]
# num feas= [[18.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_102', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108', 'bus_197', 'bus_59']
# Config good!
# Best F is (Fp Fq)= [0.09533884 0.04996082]
# num feas= [[10.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_57', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108', 'bus_197', 'bus_59', 'bus_102']
# No F found for config --> bad config
# num feas= [[0.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_7', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108', 'bus_197', 'bus_59', 'bus_102']
# Config good!
# Best F is (Fp Fq)= [0.09423192 0.049381  ]
# num feas= [[3.]]
# num tried= 225
# evaluating actuator and performance node colocated at  ['bus_151', 'bus_96', 'bus_85', 'bus_97', 'bus_83', 'bus_11', 'bus_108', 'bus_197', 'bus_59', 'bus_102', 'bus_7']
