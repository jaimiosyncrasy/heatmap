# %%
# Store config # with act/perf node strings here

# Config 1
#all_act_locs = ['bus_646']
#perf_nodes = ['bus_675']

# Config 2
#all_act_locs = ['bus_646']
#perf_nodes = ['bus_611']

# COnfig3 
#all_act_locs = ['bus_671']
#perf_nodes = ['bus_675']

# COnfig3 
#all_act_locs = ['bus_671']
#perf_nodes = ['bus_675']

# Config 4
# all_act_locs = ['bus_692']
# perf_nodes = ['bus_671']

# Config 5
# all_act_locs = ['bus_633']
# perf_nodes = ['bus_684']

# Config 6
#all_act_locs = ['bus_684']
#perf_nodes = ['bus_645']

# Config 7
#all_act_locs = ['bus_611']
#perf_nodes = ['bus_680']

# Config 8
#all_act_locs = ['bus_692','bus_684']
#perf_nodes = ['bus_633','bus_652']

# Config 9
#all_act_locs = ['bus_611']
#perf_nodes = ['bus_652']

# Config 12
#all_act_locs = ['bus_632','bus_675']
#perf_nodes = ['bus_633','bus_652']

# Config 29
#all_act_locs = ['bus_671','bus_675']
#perf_nodes = ['bus_632','bus_632']

# COnfig 30
#all_act_locs = ['bus_645','bus_646','bus_611','bus_675']
#perf_nodes = ['bus_632','bus_646','bus_671','bus_671']

# Define Complex Config 3 (infeas)
#all_act_locs = ['bus_675','bus_611','bus_652','bus_645']
#perf_nodes = ['bus_671','bus_684','bus_684','bus_632']

# Define Complex Config 4 (feas)
#all_act_locs = ['bus_611','bus_675','bus_645','bus_646']
#perf_nodes = ['bus_671','bus_671','bus_632','bus_646']

#all_act_locs = ['bus_632','bus_632','bus_645','bus_652']
#perf_nodes = ['bus_671','bus_675','bus_632','bus_652']
