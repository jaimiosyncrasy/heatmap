# %%
# Here, we display all images of heatmaps associated with paper's results section

# %%
from IPython.display import display
from PIL import Image

# shorten png printing commands into one function call
def printpng(filename):
    im = Image.open(filename) 
    #print(im.size) # (pixel width,pixel height)
    width=im.size[0]
    height=im.size[1]
    im.draft('RGB',(width/1,height/1)) 
    px = im.load()
    display(im)
    # reference on img.draft func: https://stackoverflow.com/questions/57663734/how-to-speed-up-image-loading-in-pillow-python
    
    return

# %%
# Blank IEEE 123-node test feeder
printpng('premade_figs/123NF_blank.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C9746C8>

# %%
# Motivating example configuration 1 (same configuration as CPP process except for node 60)
printpng('premade_figs/config_60.png')

# MISSING THIS ONE
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C966788>

# %%
# Motivating example configuration 2 (same configuration as CPP process except for node 60)
printpng('premade_figs/config_61.png')

# MISSING THIS ONE
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C9681C8>

# %%
# Neighborhood scenario step 7 heatmap, image is of whole feeder
printpng('premade_figs/RHP_nbhd_wideblue.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C968688>

# %%
# Neighborhood scenario step 7 heatmap, image is after cropped and neighborhoods 1 and 2 marked
printpng('premade_figs/RHP_nbhd_wideblue_cropped_markup.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x702 at 0x2A26C968C88>

# %%
# CPP Process heatmap, Motivating example, seed=3
printpng('premade_figs/heatmap_colocated_123NF.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C974C08>

# %%
# Auto-CPP, seed 2
printpng('premade_figs/actConfig_auto-CPP_seed2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C96E788>

# %%
# Auto-CPP, seed 3
printpng('premade_figs/actConfig_auto-CPP_seed3.png')

# MISSING THIS ONE
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C96ECC8>

# %%
# Auto-CPP, seed 4
printpng('premade_figs/actConfig_auto-CPP_seed4.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C971208>

# %%
# Auto-CPP, seed 5
printpng('premade_figs/actConfig_auto-CPP_seed5.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C971788>

# %%
# Auto-CPP, seed 6
printpng('premade_figs/actConfig_auto-CPP_seed6.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C971C88>

# %%
# Auto-CPP, seed 8
printpng('premade_figs/actConfig_auto-CPP_seed8.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=556x1713 at 0x2A26C9741C8>
